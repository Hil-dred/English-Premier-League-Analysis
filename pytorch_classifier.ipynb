# %%
import pandas as pd

# %%
ovr = pd.read_csv('OVR_data.csv')

# %%
ovr.head(5)
# Out:
#    Unnamed: 0          Player     Season  Born   Age          Squad    Nation  \
# 0           0            Éder  2015-2016   1987   27   Swansea City  Portugal
# 1           1   Álvaro Morata  2017-2018   1992   25        Chelsea     Spain
# 2           2   Álvaro Morata  2018-2019   1992   25        Chelsea     Spain
# 3           3  Álvaro Negredo  2016-2017   1985   30  Middlesbrough     Spain
# 4           4  Abel Hernández  2016-2017   1990   25      Hull City   Uruguay
#
#    Previous Market Value  Market Value Position  ...  Interceptions  Fouls  \
# 0                5500000       4500000       FW  ...              0     11
# 1               44000000      58500000       FW  ...              6     41
# 2               58500000      45000000       FW  ...              0     19
# 3                8250000       6750000       FW  ...             10     45
# 4                7200000       7200000       FW  ...              3     19
#
# ...

# %%
#ovr['RANK']=ovr['OVR(%)'].rank(method='max')/16
#ovr.sort_values('OVR(%)',ascending=False).head()
ovr.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Season', 'Born ', 'Age', 'Squad', 'Nation',
#        'Previous Market Value', 'Market Value', 'Position', 'App', 'Minutes',
#        'Goals', 'Passes', 'Assists', 'Yellow', 'Red', 'SubOn', 'SubOff',
#        'Shots', 'SOT', 'HitPost', 'HeadClear', 'HeadGoal', 'PKScored',
#        'FKGoal', 'Offsides', 'ThrBall', 'Misses', 'Corners', 'Crosses',
#        'Blocks', 'Interceptions', 'Fouls', 'Last man ', 'Tackles', 'ELG',
#        'OwnGoal', 'Clears', 'ABW', 'ABL', 'OVR(%)'],
#       dtype='object')

# %%
seasons = ovr.groupby(ovr['Season'])

# %%
season2015 = seasons.get_group('2018-2019')
s2015 = season2015.groupby(season2015['Position']).get_group("DF")

# %%
#s2015['Goals/avg'] = s2015['Goals']/(s2015['Goals'].sum()/len(s2015['Goals']))

# %%
#s2015.sort_values('Goals/avg',ascending=False).head()

# %%
#s2015['shots/avg']= s2015['Shots']/(s2015['Shots'].sum()/len(s2015['Shots']))
#s2015.sort_values('shots/avg',ascending=False).head()

# %%
#s2015['SOT/avg']= s2015['SOT']/(s2015['SOT'].sum()/len(s2015['SOT']))
#s2015.sort_values('SOT/avg',ascending=False).head()

# %%
#s2015['App/avg']= s2015['App']/(s2015['App'].sum()/len(s2015['App']))
#s2015.sort_values('App/avg',ascending=False).head()

# %%
s2015.head()
# Out:
#      Unnamed: 0             Player     Season  Born   Age            Squad  \
# 941           0    Aaron Cresswell  2018-2019   1989   28  West Ham United
# 945           4  Aaron Wan-Bissaka  2018-2019   1997   21   Crystal Palace
# 947           6        Adam Masina  2018-2019   1994   24          Watford
# 948           7         Adam Smith  2018-2019   1991   27  AFC Bournemouth
# 954          13    Adrian Mariappa  2018-2019   1986   31          Watford
#
#       Nation  Previous Market Value  Market Value Position  ...  \
# 941  England               13200000       9900000       DF  ...
# 945  England                 900000      31500000       DF  ...
# 947    Italy                6300000       6300000       DF  ...
# 948  England                4500000       6300000       DF  ...
# 954  Jamaica                1350000       2700000       DF  ...
#
#      Interceptions  Fouls  Last man   Tackles  ELG  OwnGoal  Clears  ABW  ABL  \
# ...

# %%
s2015['OVR'] = s2015['OVR(%)']
# Out:
# <ipython-input-198-bd37422618ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s2015['OVR'] = s2015['OVR(%)']

# %%
'''for i in range(len(s2015)):
    if s2015['Goals/avg'].iloc[i] > 7:
        s2015['Goals/avg'].iloc[i] = 5
        goals_coeff = 3 
    elif s2015['Goals/avg'].iloc[i] < 7 and  s2015['Goals/avg'].iloc[i] > 4 :
        s2015['Goals/avg'].iloc[i] = 3
        goals_coeff =  2
    elif s2015['Goals/avg'].iloc[i] < 4 :
        s2015['Goals/avg'].iloc[i] = 1
        goals_coeff =  1

    if s2015['shots/avg'].iloc[i] > 7:
        s2015['shots/avg'].iloc[i] = 5
        shots_coeff = 3
    elif s2015['shots/avg'].iloc[i] < 7 and  s2015['Goals/avg'].iloc[i] > 4 :
        s2015['shots/avg'].iloc[i] =3
        shots_coeff =  2
    elif s2015['shots/avg'].iloc[i] < 4 :
        s2015['shots/avg'].iloc[i]  =1
        shots_coeff =  1

    if s2015['SOT/avg'].iloc[i] > 7:
         s2015['SOT/avg'].iloc[i] =5
         sot_coeff = 3
    elif s2015['SOT/avg'].iloc[i] < 7 and  s2015['Goals/avg'].iloc[i] > 4 :
         s2015['SOT/avg'].iloc[i] =3
         sot_coeff =  2
    elif s2015['SOT/avg'].iloc[i] < 4 :
         s2015['SOT/avg'].iloc[i]=1
         sot_coeff =  1
    
    n=0.88

    s2015['OVR'].iloc[i] = n*s2015['Goals/avg'].iloc[i]*goals_coeff + (n**2)*s2015['shots/avg'].iloc[i]*shots_coeff + (n**3)*s2015['SOT/avg'].iloc[i]*sot_coeff'''
# Out:
# "for i in range(len(s2015)):\n    if s2015['Goals/avg'].iloc[i] > 7:\n        s2015['Goals/avg'].iloc[i] = 5\n        goals_coeff = 3 \n    elif s2015['Goals/avg'].iloc[i] < 7 and  s2015['Goals/avg'].iloc[i] > 4 :\n        s2015['Goals/avg'].iloc[i] = 3\n        goals_coeff =  2\n    elif s2015['Goals/avg'].iloc[i] < 4 :\n        s2015['Goals/avg'].iloc[i] = 1\n        goals_coeff =  1\n\n    if s2015['shots/avg'].iloc[i] > 7:\n        s2015['shots/avg'].iloc[i] = 5\n        shots_coeff = 3\n    elif s2015['shots/avg'].iloc[i] < 7 and  s2015['Goals/avg'].iloc[i] > 4 :\n        s2015['shots/avg'].iloc[i] =3\n        shots_coeff =  2\n    elif s2015['shots/avg'].iloc[i] < 4 :\n        s2015['shots/avg'].iloc[i]  =1\n        shots_coeff =  1\n\n    if s2015['SOT/avg'].iloc[i] > 7:\n         s2015['SOT/avg'].iloc[i] =5\n         sot_coeff = 3\n    elif s2015['SOT/avg'].iloc[i] < 7 and  s2015['Goals/avg'].iloc[i] > 4 :\n         s2015['SOT/avg'].iloc[i] =3\n         sot_coeff =  2\n    el
# ...

# %%
#s2015['RANK']=s2015['OVR'].rank(method='max')

#s2015.sort_values('OVR',ascending=False).head()

# %%
#s2015.sort_values('RANK',ascending=True).head(5)

# %%
'''s2015["Goals_Rank"] = s2015['Goals'].rank(pct=True)
s2015["shots_Rank"] = s2015['Shots'].rank(pct=True)
s2015["sot_Rank"] = s2015['SOT'].rank(pct=True)'''
# Out:
# 's2015["Goals_Rank"] = s2015[\'Goals\'].rank(pct=True)\ns2015["shots_Rank"] = s2015[\'Shots\'].rank(pct=True)\ns2015["sot_Rank"] = s2015[\'SOT\'].rank(pct=True)'

# %%
s2015.head()
# Out:
#      Unnamed: 0             Player     Season  Born   Age            Squad  \
# 941           0    Aaron Cresswell  2018-2019   1989   28  West Ham United
# 945           4  Aaron Wan-Bissaka  2018-2019   1997   21   Crystal Palace
# 947           6        Adam Masina  2018-2019   1994   24          Watford
# 948           7         Adam Smith  2018-2019   1991   27  AFC Bournemouth
# 954          13    Adrian Mariappa  2018-2019   1986   31          Watford
#
#       Nation  Previous Market Value  Market Value Position  ...  Fouls  \
# 941  England               13200000       9900000       DF  ...      2
# 945  England                 900000      31500000       DF  ...     23
# 947    Italy                6300000       6300000       DF  ...     17
# 948  England                4500000       6300000       DF  ...     18
# 954  Jamaica                1350000       2700000       DF  ...     19
#
#      Last man   Tackles  ELG  OwnGoal  Clears  ABW  ABL  OVR(%)   OVR
# ...

# %%
s2015.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Season', 'Born ', 'Age', 'Squad', 'Nation',
#        'Previous Market Value', 'Market Value', 'Position', 'App', 'Minutes',
#        'Goals', 'Passes', 'Assists', 'Yellow', 'Red', 'SubOn', 'SubOff',
#        'Shots', 'SOT', 'HitPost', 'HeadClear', 'HeadGoal', 'PKScored',
#        'FKGoal', 'Offsides', 'ThrBall', 'Misses', 'Corners', 'Crosses',
#        'Blocks', 'Interceptions', 'Fouls', 'Last man ', 'Tackles', 'ELG',
#        'OwnGoal', 'Clears', 'ABW', 'ABL', 'OVR(%)', 'OVR'],
#       dtype='object')

# %%
s2015["goals_Rank"] = s2015['Goals'].rank(pct=True)
s2015["passes_Rank"] = s2015['Passes'].rank(pct=True)
s2015["HeadClear_Rank"] = s2015['HeadClear'].rank(pct=True)
s2015["Blocks_Rank"] = s2015['Blocks'].rank(pct=True)
s2015["HeadGoal_Rank"] = s2015['HeadGoal'].rank(pct=True)
s2015['Interceptions_Rank'] = s2015['Interceptions'].rank(pct=True)
s2015["tackles_Rank"] = s2015['Tackles'].rank(pct=True)
# Out:
# <ipython-input-207-f82288172df2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s2015["goals_Rank"] = s2015['Goals'].rank(pct=True)
# <ipython-input-207-f82288172df2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s2015["passes_Rank"] = s2015['Passes'].rank(pct=True)
# <ipython-input-207-f82288172df2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
for i in range(len(s2015)):
    s2015['OVR'].iloc[i] = int((s2015['goals_Rank'].iloc[i]*0.1 +  s2015['tackles_Rank'].iloc[i]*0.2 + s2015['passes_Rank'].iloc[i]*0.1 + s2015['Blocks_Rank'].iloc[i]*0.20+ s2015['HeadGoal_Rank'].iloc[i]*0.1 + s2015['Interceptions_Rank'].iloc[i]*0.20+ s2015['HeadClear_Rank'].iloc[i]*0.10)*100)
s2015.head()
# Out:
# /home/obafemi/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#      Unnamed: 0             Player     Season  Born   Age            Squad  \
# 941           0    Aaron Cresswell  2018-2019   1989   28  West Ham United
# 945           4  Aaron Wan-Bissaka  2018-2019   1997   21   Crystal Palace
# 947           6        Adam Masina  2018-2019   1994   24          Watford
# 948           7         Adam Smith  2018-2019   1991   27  AFC Bournemouth
# 954          13    Adrian Mariappa  2018-2019   1986   31          Watford
#
#       Nation  Previous Market Value  Market Value Position  ...  ABL  OVR(%)  \
# 941  England               13200000       9900000       DF  ...   18    24.6
# ...

# %%
s2015.sort_values('OVR',ascending=True).head(20)
# Out:
#       Unnamed: 0                Player     Season  Born   Age  \
# 1118         177               Emerson  2018-2019   1994   24
# 1113         172            Diego Rico  2018-2019   1993   25
# 1363         422         Rúben Vinagre  2018-2019   1999   19
# 1119         178           Eric Bailly  2018-2019   1994   24
# 1416         475  Stephan Lichtsteiner  2018-2019   1984   34
# 1114         173           Diogo Dalot  2018-2019   1999   19
# 1014          73        Benjamin Mendy  2018-2019   1994   24
# 1430         489   Timothy Fosu-Mensah  2018-2019   1998   20
# 1220         279          Jonjoe Kenny  2018-2019   1997   21
# 1023          82                 Bruno  2018-2019   1980   38
# 1052         111          Chris Mepham  2018-2019   1997   20
# 1197         256      Javier Manquillo  2018-2019   1994   24
# 1085         144                Danilo  2018-2019   1991   27
# 1437         496           Tommy Smith  2018-2019   1992   26
# ...
